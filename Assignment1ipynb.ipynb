# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing the dataset

# %%
dataset = pd.read_csv('breast-cancer.csv')

# %% [markdown]
# # Checking the shape of the dataset

# %%
# Checking the shape of the dataset
dataset.shape
# Out:
# (569, 33)

# %% [markdown]
# # Information of the dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# # Description of the Dataset

# %%
dataset.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# # Checking the null values in the dataset

# %%
dataset.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# # Indexing and selecting data

# %%
dataset.iloc[2:5]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 2           0.1096            0.1599          0.1974               0.1279
# 3           0.1425            0.2839          0.2414               0.1052
# 4           0.1003            0.1328          0.1980               0.1043
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# ...

# %%
#Printing the data except the last column
dataset.iloc[:, :-1].values
# Out:
# array([[842302, 'M', 17.99, ..., 0.2654, 0.4601, 0.1189],
#        [842517, 'M', 20.57, ..., 0.186, 0.275, 0.08902],
#        [84300903, 'M', 19.69, ..., 0.243, 0.3613, 0.08758],
#        ...,
#        [926954, 'M', 16.6, ..., 0.1418, 0.2218, 0.0782],
#        [927241, 'M', 20.6, ..., 0.265, 0.4087, 0.124],
#        [92751, 'B', 7.76, ..., 0.0, 0.2871, 0.07039]], dtype=object)

# %% [markdown]
# # Sorting the data by its columns/features

# %%
df1 = dataset.sort_values(by='radius_mean', ascending=True)
print(df1)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 101     862722         B        6.981         13.43           43.79
# 539     921362         B        7.691         25.44           48.34
# 538     921092         B        7.729         25.49           47.98
# 568      92751         B        7.760         24.54           47.92
# 46    85713702         B        8.196         16.84           51.71
# ..         ...       ...          ...           ...             ...
# 82     8611555         M       25.220         24.91          171.50
# 352     899987         M       25.730         17.46          174.20
# 180     873592         M       27.220         21.87          182.10
# 461  911296202         M       27.420         26.27          186.90
# 212    8810703         M       28.110         18.47          188.50
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 101      143.5          0.11700           0.07568         0.00000
# ...

# %%
df2 = dataset.sort_values(by='perimeter_mean', ascending=True)
print(df2)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 101     862722         B        6.981         13.43           43.79
# 568      92751         B        7.760         24.54           47.92
# 538     921092         B        7.729         25.49           47.98
# 539     921362         B        7.691         25.44           48.34
# 46    85713702         B        8.196         16.84           51.71
# ..         ...       ...          ...           ...             ...
# 82     8611555         M       25.220         24.91          171.50
# 352     899987         M       25.730         17.46          174.20
# 180     873592         M       27.220         21.87          182.10
# 461  911296202         M       27.420         26.27          186.90
# 212    8810703         M       28.110         18.47          188.50
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 101      143.5          0.11700           0.07568         0.00000
# ...

# %%
df3 = dataset.sort_values(by = 'concavity_mean' , ascending = True)
print(df3)
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 568      92751         B        7.760         24.54           47.92
# 314     894047         B        8.597         18.60           54.09
# 538     921092         B        7.729         25.49           47.98
# 101     862722         B        6.981         13.43           43.79
# 192     875099         B        9.720         18.22           60.73
# ..         ...       ...          ...           ...             ...
# 461  911296202         M       27.420         26.27          186.90
# 78     8610862         M       20.180         23.97          143.70
# 152    8710441         B        9.731         15.34           63.78
# 108      86355         M       22.270         19.67          152.80
# 122     865423         M       24.250         20.20          166.20
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 568      181.0          0.05263           0.04362          0.0000
# ...

# %% [markdown]
# # Showing the value count of the specific columns

# %%
count_1 = dataset['symmetry_mean'].value_counts()
print(count_1)
# Out:
# symmetry_mean
# 0.1714    4
# 0.1769    4
# 0.1893    4
# 0.1601    4
# 0.1717    4
#          ..
# 0.2251    1
# 0.2200    1
# 0.1979    1
# 0.1950    1
# 0.1587    1
# Name: count, Length: 432, dtype: int64

# %%
count_2 = dataset['concave points_worst'].value_counts()
print(count_2)
# Out:
# concave points_worst
# 0.00000    13
# 0.05556     3
# 0.06296     3
# 0.12180     3
# 0.07431     3
#            ..
# 0.15410     1
# 0.29030     1
# 0.26880     1
# 0.03990     1
# 0.26500     1
# Name: count, Length: 492, dtype: int64

# %% [markdown]
# # Converting the datatypes of the columns of the dataset

# %%
dataset1= dataset['area_worst'].astype(float)
print(dataset1)
# Out:
# 0      2019.0
# 1      1956.0
# 2      1709.0
# 3       567.0
# 4      1575.0
#         ...
# 564    2027.0
# 565    1731.0
# 566    1124.0
# 567    1821.0
# 568     268.0
# Name: area_worst, Length: 569, dtype: float64

# %%
dataset2 = dataset['compactness_worst'].astype(int)
print(dataset2)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    0
# Name: compactness_worst, Length: 569, dtype: int64
